# %%
5.	데이터 분석
6.	데이터 시각화
7.	데이터 또는 분석 과정 차별화 포인트 

# 연도별 발생건수 시각화
plt.figure(figsize=(10, 6))
for crime_type in df.columns[2:]:
    if '사이버사기(직거래)' in crime_type and '발생건수' in crime_type:
        plt.plot(df['연도'], df[crime_type], label=crime_type.split('(')[0])  # 범죄 유형에서 괄호 이전 부분을 사용하여 레이블 생성
plt.xlabel('연도')
plt.ylabel('건수')
plt.title('연도별 사이버사기(직거래)범죄 발생건수')
plt.legend()
plt.show()


8.	데이터분석 수업을 마감하며 
인문대학 학생으로서 융합전공으로 컴퓨터 공학과 과정을 밟고 있는 학생으로서, 쉽지 않았습니다. 
공공데이터 품질 진단 및 확인 업무를 인턴으로 체험해본 경험만 생각하여 너무 가볍게 접근했던 것 같습니다.
같은 학기에 진행했던 파이썬 수업 덕분에 파이썬을 이해하는 데 큰 어려움은 없었지만, 그래도 실습 중심의, 학습법을 통해서 어느정도 이론과 필요성은 알고
넘어 가는 수업이 된 것 같습니다. 
기말고사로 내주신 이번 프로젝트가 가장 크게 다가오는 것 같습니다. 이해가 안되던 내용들이 이번 프로젝트를 위한
공공데이터를 구하면서, 어떤 데이터가 분석하기 좋은가, 어떤식으로 분석하는 것이 좋은가가 확실하게 체감이 된 것 같습니다.
중복되는 데이터셋이라 할지라도, 어떻게 활용하는 가에 따라 다른 결과가 나올 수 있다는 것을 알았고,
데이터 분석 분야는 데이터를 분석하는 사람의 사고방식이 굉장히 중요한 분야라는 것을 느꼈던 기말고사 프로젝트였습니다.

# %%
# 연도가 지날 수록 증가하는 범죄 유형 시각화
plt.figure(figsize=(10, 6))
for crime_type in df_new['범죄유형'].unique():
    data = df_new[df_new['범죄유형'] == crime_type]
    plt.plot(data['연도'], data['발생건수'], label=crime_type)
plt.xlabel('연도')
plt.ylabel('발생건수')
plt.title('연도별 발생건수 추이')
plt.legend()
plt.show()

# 연도가 지날 수록 감소하는 범죄 유형 시각화
plt.figure(figsize=(10, 6))
for crime_type in df_new['범죄유형'].unique():
    data = df_new[df_new['범죄유형'] == crime_type]
    plt.plot(data['연도'], data['발생건수'], label=crime_type)
plt.xlabel('연도')
plt.ylabel('발생건수')
plt.title('연도별 발생건수 감소 추이')
plt.legend()
plt.show()

# 연도가 지날 수록 증가하는 검거율 시각화
plt.figure(figsize=(10, 6))
for crime_type in df_new['범죄유형'].unique():
    data = df_new[df_new['범죄유형'] == crime_type]
    plt.plot(data['연도'], data['검거율'], label=crime_type)
plt.xlabel('연도')
plt.ylabel('검거율')
plt.title('연도별 검거율 증가 추이')
plt.legend()
plt.show()

# 연도가 지날 수록 감소하는 검거율 시각화
plt.figure(figsize=(10, 6))
for crime_type in df_new['범죄유형'].unique():
    data = df_new[df_new['범죄유형'] == crime_type]
    plt.plot(data['연도'], data['검거율'], label=crime_type)
plt.xlabel('연도')
plt.ylabel('검거율')
plt.title('연도별 검거율 감소 추이')
plt.legend()
plt.show()

# %%
# 데이터시각화 테스트 1: 특정 범죄 유형의 발생건수 시각화
# 특정 범죄 유형 정의
specific_crime_type = ['사이버금융범죄(기타)']

plt.figure(figsize=(10, 6))
for crime_type in specific_crime_type:
    plt.plot(df_new.index, df_new[f'{crime_type}_발생건수'], label=f'{crime_type}_발생건수')
plt.xlabel('연도')
plt.ylabel('발생건수')
plt.title('연도별 범죄 발생건수 추이')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# 예시: 특정 범죄 유형의 검거율 시각화
plt.figure(figsize=(10, 6))
for crime_type in specific_crime_type:
    plt.plot(df_new.index, df_new[f'{crime_type}_검거율'], label=f'{crime_type}_검거율')
plt.xlabel('연도')
plt.ylabel('검거율')
plt.title('연도별 범죄 검거율 추이')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
